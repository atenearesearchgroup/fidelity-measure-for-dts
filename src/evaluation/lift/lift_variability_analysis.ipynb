# %%
import os

os.environ['NPY_ALLOW_MULTIPLE_DLLS'] = '1'

from result_analysis.statistical_graphics import generate_parallel_behavior_graphic, \
    generate_statistical_info_stairs_variability

# %%
# FILE PATHS
current_directory = os.path.abspath(os.path.join(os.getcwd(), '../../'))
input_directory = current_directory + "/resources/input/lift/"
output_directory = current_directory + "/resources/output/evaluation/lift/"
output_dir_var = output_directory + "/variability_good/results/"

# DIGITAL TWIN
dt_path = input_directory + "04.5-simulation/"
dt_file = ["cutBajada_4_0_4.csv", "cutBajada_4_2_0_2_4.csv", "cutBajada_4_3_2_1_0_1_2_3_4.csv"]

# PHYSICAL TWIN
pt_path = input_directory + "03-derived_values/"
pt_files = ["Bajada_4_0_4_", "Bajada_4_2_0_2_4_", "Bajada_4_3_2_1_0_1_2_3_4_"]

# ANALYSIS PARAMETERS
timestamp_label = "timestamp(s)"
param_interest = "accel(m/s2)"
tolerance_label = "mad_accel(m/s2)"

# %%
# Scenario 4-0-4 - Variability analysis
scenario = f'{pt_files[0]}01.csv'
fig = generate_parallel_behavior_graphic(timestamp_label,
                                         timestamp_label,
                                         param_interest,
                                         param_interest,
                                         pt_path + scenario,
                                         dt_path + dt_file[0])

fig.write_image(f'{output_dir_var}/results/{os.path.splitext(dt_file[0])[0]}{scenario}.pdf', format="pdf", width=1750,
                height=800)
# Out:
# <div>                            <div id="81d41ebb-f714-4a1f-b8b0-bbe1168724ea" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("81d41ebb-f714-4a1f-b8b0-bbe1168724ea")) {                    Plotly.newPlot(                        "81d41ebb-f714-4a1f-b8b0-bbe1168724ea",                        [{"line":{"width":1},"marker":{"line":{"width":0.5},"size":3},"mode":"lines+markers","name":"PT Trajectory","x":[0.05,0.0,0.0989999999947031,0.1990000000005238,0.2969999999986612,0.396999999997206,0.4939999999987776,0.5930000000007567,0.6919999999954598,0.7909999999974389,0.8899999999994179,0.9879999999975552,1.0879999999961,1.187999999994645,1.2849999999962165,1.3879999999990105,1.4830000000001746,1.5939999999973224,1.6809999999968568,1.7959999999948195,1.8779999
# ...

# %%
fig = generate_statistical_info_stairs_variability(tolerance_label,
                                                   output_dir_var,
                                                   os.path.splitext(dt_file[0])[0])
fig.write_image(f'{output_dir_var}/results/4_0_4_mad_analysis.pdf',
                format="pdf", width=1750, height=800)
# Out:
# <div>                            <div id="d2764c11-5388-419a-ab81-ca920344acf2" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d2764c11-5388-419a-ab81-ca920344acf2")) {                    Plotly.newPlot(                        "d2764c11-5388-419a-ab81-ca920344acf2",                        [{"mode":"lines+markers","x":[0.0,0.02,0.04,0.06,0.08,0.1,0.12,0.14,0.16,0.18,0.2,0.22,0.24,0.26,0.28,0.3],"y":[0.0,55.093525179856115,75.12230215827338,84.41726618705036,89.23741007194243,90.7913669064748,91.59712230215827,91.76978417266186,91.98561151079136,92.07194244604317,92.14388489208633,92.23021582733813,92.33093525179855,92.37410071942445,92.37410071942445,92.38848920863309],"type":"scatter","xaxis":"x","yaxis":"y"},{"line":{"width":0.1},"mode":"lines","n
# ...

# %%
# Scenario 4-2-0-2-4 - Variability Analysis
scenario = f'{pt_files[1]}01.csv'
fig = generate_parallel_behavior_graphic(timestamp_label,
                                         timestamp_label,
                                         param_interest,
                                         param_interest,
                                         pt_path + scenario,
                                         dt_path + dt_file[1])

fig.write_image(f'{output_dir_var}/results/{os.path.splitext(dt_file[1])[0]}_{pt_files[1]}01.pdf', format="pdf", width=1750,
                height=800)
# Out:
# <div>                            <div id="bbd628db-0722-4903-b0e3-da5a811722d3" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("bbd628db-0722-4903-b0e3-da5a811722d3")) {                    Plotly.newPlot(                        "bbd628db-0722-4903-b0e3-da5a811722d3",                        [{"line":{"width":1},"marker":{"line":{"width":0.5},"size":3},"mode":"lines+markers","name":"PT Trajectory","x":[0.05,0.0,0.097,0.196,0.308,0.393,0.541,0.591,0.69,0.817,0.888,1.019,1.086,1.194,1.283,1.382,1.48,1.616,1.678,1.822,1.875,2.031,2.073,2.255,2.27,2.37,2.468,2.614,2.666,2.823,2.863,3.031,3.062,3.24,3.259,3.357,3.46,3.555,3.656,3.752,3.857,3.95,4.077,4.148,4.278,4.346,4.482,4.543,4.7,4.741,4.839,4.938,5.097,5.136,5.305,5.333,5.515,5.53,5.63,5.728,5.827,5.9
# ...

# %%
fig = generate_statistical_info_stairs_variability(tolerance_label,
                                                   output_dir_var,
                                                   os.path.splitext(dt_file[1])[0] + os.path.splitext(pt_files[1])[0])

fig.write_image(f'{output_dir_var}/results/4_2_0_2_4_mad_analysis.pdf',
                format="pdf", width=1750, height=800)
# Out:
# <div>                            <div id="135170db-0a8d-4b8e-bdda-89984c642494" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("135170db-0a8d-4b8e-bdda-89984c642494")) {                    Plotly.newPlot(                        "135170db-0a8d-4b8e-bdda-89984c642494",                        [{"mode":"lines+markers","x":[0.0,0.02,0.04,0.06,0.08,0.1,0.12,0.14,0.16,0.18,0.2,0.22,0.24,0.26,0.28,0.3],"y":[0.0,65.1892890120037,81.56355801785163,89.1658971991382,92.82856263465682,94.27516158818098,94.61372730070792,94.8599569098184,95.01385041551248,95.19852262234532,95.32163742690058,95.3524161280394,95.53708833487228,95.56786703601108,95.56786703601108,95.59864573714991],"type":"scatter","xaxis":"x","yaxis":"y"},{"line":{"width":0.1},"mode":"lines","name"
# ...

# %%
# Scenario 4 - 3 - 2 - 1 - 0 - 1 - 2 - 3 - 4
scenario = f'{pt_files[2]}01.csv'
fig = generate_parallel_behavior_graphic(timestamp_label,
                                         timestamp_label,
                                         param_interest,
                                         param_interest,
                                         pt_path + scenario,
                                         dt_path + dt_file[2])

fig.write_image(f'{output_dir_var}/results/{os.path.splitext(dt_file[2])[0]}_{pt_files[1]}01.pdf', format="pdf", width=1750,
                height=800)
# Out:
# <div>                            <div id="8b2d493c-3163-4b3c-a51e-238053313992" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8b2d493c-3163-4b3c-a51e-238053313992")) {                    Plotly.newPlot(                        "8b2d493c-3163-4b3c-a51e-238053313992",                        [{"line":{"width":1},"marker":{"line":{"width":0.5},"size":3},"mode":"lines+markers","name":"PT Trajectory","x":[0.05,0.0,0.098,0.197,0.324,0.393,0.493,0.592,0.704,0.789,0.926,0.987,1.086,1.184,1.298,1.381,1.481,1.579,1.678,1.778,1.915,1.974,2.073,2.172,2.271,2.371,2.468,2.566,2.667,2.764,2.863,2.962,3.06,3.168,3.259,3.358,3.456,3.554,3.653,3.753,3.851,3.979,4.049,4.148,4.246,4.37,4.443,4.542,4.64,4.769,4.839,4.937,5.036,5.139,5.233,5.356,5.431,5.529,5.628,5.727,5
# ...

# %%
fig = generate_statistical_info_stairs_variability(tolerance_label,
                                                   output_dir_var,
                                                   os.path.splitext(dt_file[2])[0] + os.path.splitext(pt_files[2])[0])

fig.write_image(f'{output_dir_var}/results/4_3_2_1_0_1_2_3_4_mad_analysis.pdf',
                format="pdf", width=1750, height=800)
# Out:
# <div>                            <div id="e6b9f2f0-b9cb-4662-9e23-2d68ea209556" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e6b9f2f0-b9cb-4662-9e23-2d68ea209556")) {                    Plotly.newPlot(                        "e6b9f2f0-b9cb-4662-9e23-2d68ea209556",                        [{"mode":"lines+markers","x":[0.0,0.02,0.04,0.06,0.08,0.1,0.12,0.14,0.16,0.18,0.2,0.22,0.24,0.26,0.28,0.3],"y":[0.0,66.98604807530677,82.95511850731215,89.22507984535217,91.27584467977812,92.3012270969911,92.72146579257019,92.88956127080182,92.9399899142713,92.9399899142713,92.99041855774078,93.04084720121028,93.05765674903346,93.07446629685661,93.07446629685661,93.07446629685661],"type":"scatter","xaxis":"x","yaxis":"y"},{"line":{"width":0.1},"mode":"lines","name
# ...

# %%
fig = generate_statistical_info_stairs_variability(tolerance_label,
                                             output_dir_var,
                                             "")

fig.write_image(f'{output_dir_var}/results/mad_analysis_elevator.pdf',
                format="pdf", width=1750, height=800)
# Out:
# <div>                            <div id="fcc1e269-3070-426f-afec-ea9d7fa7ccf7" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("fcc1e269-3070-426f-afec-ea9d7fa7ccf7")) {                    Plotly.newPlot(                        "fcc1e269-3070-426f-afec-ea9d7fa7ccf7",                        [{"mode":"lines+markers","x":[0.0,0.02,0.04,0.06,0.08,0.1,0.12,0.14,0.16,0.18,0.2,0.22,0.24,0.26,0.28,0.3],"y":[0.0,59.21632894128078,77.79869069738908,86.2090995627484,90.29295766642059,91.72767719501653,92.37355014383856,92.55914976677997,92.73235225607905,92.8209351293926,92.89843855467421,92.96762176632063,93.06834923560642,93.10425044955298,93.10425044955298,93.1190142617719],"type":"scatter","xaxis":"x","yaxis":"y"},{"line":{"width":0.1},"mode":"lines","name
# ...
