# %% [markdown]
# # Gap Tuning for the Incubator
# This Jupyter Notebook plots the fidelity metrics for the two incubator scenarios and performs a change point analysis and linear regression on the input data to analyze the influence and statistical significance of the MAD, opening, and extending gap parameters on the fidelity metrics (% matched snapshots, Frèchet distance, Euclidean distance).
#
# It takes the information stored in */resources/output/incubator/gap_tuning* from previously performed alignments and executes the corresponding computations.
#
# In this case, to properly detect the change point, we ordered the algorithm to look for two changes. The second one is the one chosen for the analysis in the technical report.

# %% [markdown]
# ## Imports and constants

# %%
import os

import matplotlib.pyplot as plt
import ruptures as rpt
import pandas as pd
from util import generate_sublist

from result_analysis import get_change_point
from result_analysis.gap_tunning import execute_regression

from IPython.display import Markdown, HTML

current_directory = os.path.abspath(os.path.join(os.getcwd(), '../../'))
output_directory = current_directory + '/resources/output/incubator/gap_tuning/results/'

files = ['2P_exp1_ht3_hg2_2P_Modelexp1_ht3_hg2_Real.csv',
         '4P_exp1_ht3_hg2_4P_Modelexp1_ht3_hg2_Real.csv']

param_interest = 'temperature(degrees)'

params = [f'mad_{param_interest}',
          'init_gap',
          'cont_gap',
          'percentage_matched_snapshots',
          'frechet_euclidean',
          'p2p_mean_euclidean_mean',
          'number_of_gaps',
          'mean_length_gaps_mean']

params_labels = [f'MAD temp (ºC)',
                 'Penalty Opening Gap',
                 'Penalty Extending Gap',
                 '%matched snapshots',
                 'Frèchet euclidean',
                 'Euclidean Avg',
                 'Number of gaps',
                 'Avg length of gaps']

# It orders first by %matched snapshots and then by number of gaps, to visually analyse their influence over other parameters
ordering_params = [3, 6]
# In the first graphic, we include the fidelity metrics and in the second, the gap statistics
include_params = [[(0, 5)], [(0, 3), (6, 7)]]
filters = {'affine': ['init_gap', lambda x: x < 0.0],
           'simple' : ['init_gap', lambda x: x == 0.0]}
assert(len(ordering_params) == len(include_params))

text_content = ''

# %% [markdown]
# ## Change point analysis and linear regression

# %%
for file in files:
    display(Markdown(f'# Scenario {file.replace("_", " ").replace(".csv", "")}\n'))
    df = pd.read_csv(f'{output_directory}{file}')
    for gap_type, values in filters.items():
        display(Markdown(f'## {gap_type.capitalize()} Gap\n'))
        # Filter the values to perform the analysis of the affine or the simple gap
        filtered_df = df[values[1](df[values[0]])]
        result_prev = None
        for index, ordering_param in enumerate(ordering_params):
            display(Markdown(f'### Ordered by {params_labels[ordering_param]}\n'))
            selected_params = generate_sublist(params, include_params[index])
            selected_label_params = generate_sublist(params_labels, include_params[index])

            # It performs the change point analysis: Given a segment model, it computes the best partition
            # In this case, we configured it to look for two changes and we keep this second change as change point for the analysis in the technical report.
            signals, result = get_change_point(filtered_df,
                                               [selected_params[0], params[ordering_param]],
                                               selected_params, number_of_changes=2)

            # To keep the change point of the first graphic in the gap analysis
            if not result_prev:
                result_prev = result
            _, axs = rpt.display(signals, result_prev[-2:])

            for i, label in enumerate(selected_label_params):
                axs[i].set_ylabel(label)

            plt.tight_layout()
            plt.savefig(f'{output_directory}/output_{gap_type}_{"a" if index == 0 else "b"}_{os.path.splitext(file)[0]}.pdf', format='pdf')
            plt.show()

        display(Markdown(f'### Analysis all samples\n'))
        display(HTML(execute_regression(df, 0, param_interest).summary().as_html()))
        display(Markdown(f'### Analysis segment\n'))
        # After performing the change point analysis, 75% is the percentage in which the change point is detected.
        display(HTML(execute_regression(df, 75, param_interest).summary().as_html()))
# Out:
# # Scenario 2P exp1 ht3 hg2 2P Modelexp1 ht3 hg2 Real
# ## Affine Gap
# ### Ordered by %matched snapshots
# ### Ordered by Number of gaps
# ### Analysis all samples
# <table class="simpletable">
# <caption>OLS Regression Results</caption>
# <tr>
#   <th>Dep. Variable:</th>    <td>percentage_matched_snapshots</td> <th>  R-squared:         </th> <td>   0.871</td>
# </tr>
# <tr>
#   <th>Model:</th>                         <td>OLS</td>             <th>  Adj. R-squared:    </th> <td>   0.870</td>
# </tr>
# <tr>
#   <th>Method:</th>                   <td>Least Squares</td>        <th>  F-statistic:       </th> <td>   1876.</td>
# </tr>
# <tr>
#   <th>Date:</th>                   <td>Fri, 28 Jul 2023</td>       <th>  Prob (F-statistic):</th>  <td>  0.00</td>
# </tr>
# <tr>
#   <th>Time:</th>                       <td>21:55:33</td>           <th>  Log-Likelihood:    </th> <td> -2680.8</td>
# </tr>
# <tr>
#   <th>No. Observations:</th>            <td>   840</td>            <th>  AIC:               </th> <td>   5370.</td>
# </tr>
# <tr>
#   <th>Df Residuals:</th>                <td>   836</td>            <th>  BIC:               </th> <td>   5389.</td>
# </tr>
# <tr>
#   <th>Df Model:</th>                    <td>     3</td>            <th>                     </th>     <td> </td>
# </tr>
# <tr>
#   <th>Covariance Type:</th>            <td>nonrobust</td>          <th>                     </th>     <td> </td>
# </tr>
# </table>
# <table class="simpletable">
# <tr>
#               <td></td>                <th>coef</th>     <th>std err</th>      <th>t</th>      <th>P>|t|</th>  <th>[0.025</th>    <th>0.975]</th>
# </tr>
# <tr>
#   <th>const</th>                    <td>   75.5983</td> <td>    1.035</td> <td>   73.044</td> <td> 0.000</td> <td>   73.567</td> <td>   77.630</td>
# </tr>
# <tr>
#   <th>init_gap</th>                 <td>    4.0316</td> <td>    0.204</td> <td>   19.806</td> <td> 0.000</td> <td>    3.632</td> <td>    4.431</td>
# </tr>
# <tr>
#   <th>cont_gap</th>                 <td>   25.0035</td> <td>    0.353</td> <td>   70.830</td> <td> 0.000</td> <td>   24.311</td> <td>   25.696</td>
# </tr>
# <tr>
#   <th>mad_temperature(degrees)</th> <td>   87.9531</td> <td>    5.959</td> <td>   14.759</td> <td> 0.000</td> <td>   76.256</td> <td>   99.650</td>
# </tr>
# </table>
# <table class="simpletable">
# <tr>
#   <th>Omnibus:</th>       <td>93.543</td> <th>  Durbin-Watson:     </th> <td>   0.454</td>
# </tr>
# <tr>
#   <th>Prob(Omnibus):</th> <td> 0.000</td> <th>  Jarque-Bera (JB):  </th> <td>  26.634</td>
# </tr>
# <tr>
#   <th>Skew:</th>          <td>-0.039</td> <th>  Prob(JB):          </th> <td>1.65e-06</td>
# </tr>
# <tr>
#   <th>Kurtosis:</th>      <td> 2.131</td> <th>  Cond. No.          </th> <td>    66.3</td>
# </tr>
# </table><br/><br/>Notes:<br/>[1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# ### Analysis segment
# <table class="simpletable">
# <caption>OLS Regression Results</caption>
# <tr>
#   <th>Dep. Variable:</th>    <td>percentage_matched_snapshots</td> <th>  R-squared:         </th> <td>   0.669</td>
# </tr>
# <tr>
#   <th>Model:</th>                         <td>OLS</td>             <th>  Adj. R-squared:    </th> <td>   0.664</td>
# </tr>
# <tr>
#   <th>Method:</th>                   <td>Least Squares</td>        <th>  F-statistic:       </th> <td>   144.0</td>
# </tr>
# <tr>
#   <th>Date:</th>                   <td>Fri, 28 Jul 2023</td>       <th>  Prob (F-statistic):</th> <td>4.42e-51</td>
# </tr>
# <tr>
#   <th>Time:</th>                       <td>21:55:33</td>           <th>  Log-Likelihood:    </th> <td> -284.36</td>
# </tr>
# <tr>
#   <th>No. Observations:</th>            <td>   218</td>            <th>  AIC:               </th> <td>   576.7</td>
# </tr>
# <tr>
#   <th>Df Residuals:</th>                <td>   214</td>            <th>  BIC:               </th> <td>   590.3</td>
# </tr>
# <tr>
#   <th>Df Model:</th>                    <td>     3</td>            <th>                     </th>     <td> </td>
# </tr>
# <tr>
#   <th>Covariance Type:</th>            <td>nonrobust</td>          <th>                     </th>     <td> </td>
# </tr>
# </table>
# <table class="simpletable">
# <tr>
#               <td></td>                <th>coef</th>     <th>std err</th>      <th>t</th>      <th>P>|t|</th>  <th>[0.025</th>    <th>0.975]</th>
# </tr>
# <tr>
#   <th>const</th>                    <td>   73.7814</td> <td>    0.310</td> <td>  238.207</td> <td> 0.000</td> <td>   73.171</td> <td>   74.392</td>
# </tr>
# <tr>
#   <th>init_gap</th>                 <td>    0.7284</td> <td>    0.072</td> <td>   10.167</td> <td> 0.000</td> <td>    0.587</td> <td>    0.870</td>
# </tr>
# <tr>
#   <th>cont_gap</th>                 <td>    2.8568</td> <td>    0.326</td> <td>    8.771</td> <td> 0.000</td> <td>    2.215</td> <td>    3.499</td>
# </tr>
# <tr>
#   <th>mad_temperature(degrees)</th> <td>   37.8445</td> <td>    1.915</td> <td>   19.759</td> <td> 0.000</td> <td>   34.069</td> <td>   41.620</td>
# </tr>
# </table>
# <table class="simpletable">
# <tr>
#   <th>Omnibus:</th>       <td>58.221</td> <th>  Durbin-Watson:     </th> <td>   1.265</td>
# </tr>
# <tr>
#   <th>Prob(Omnibus):</th> <td> 0.000</td> <th>  Jarque-Bera (JB):  </th> <td> 118.485</td>
# </tr>
# <tr>
#   <th>Skew:</th>          <td>-1.293</td> <th>  Prob(JB):          </th> <td>1.87e-26</td>
# </tr>
# <tr>
#   <th>Kurtosis:</th>      <td> 5.520</td> <th>  Cond. No.          </th> <td>    54.6</td>
# </tr>
# </table><br/><br/>Notes:<br/>[1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# ## Simple Gap
# ### Ordered by %matched snapshots
# ### Ordered by Number of gaps
# ### Analysis all samples
# <table class="simpletable">
# <caption>OLS Regression Results</caption>
# <tr>
#   <th>Dep. Variable:</th>    <td>percentage_matched_snapshots</td> <th>  R-squared:         </th> <td>   0.871</td>
# </tr>
# <tr>
#   <th>Model:</th>                         <td>OLS</td>             <th>  Adj. R-squared:    </th> <td>   0.870</td>
# </tr>
# <tr>
#   <th>Method:</th>                   <td>Least Squares</td>        <th>  F-statistic:       </th> <td>   1876.</td>
# </tr>
# <tr>
#   <th>Date:</th>                   <td>Fri, 28 Jul 2023</td>       <th>  Prob (F-statistic):</th>  <td>  0.00</td>
# </tr>
# <tr>
#   <th>Time:</th>                       <td>21:55:36</td>           <th>  Log-Likelihood:    </th> <td> -2680.8</td>
# </tr>
# <tr>
#   <th>No. Observations:</th>            <td>   840</td>            <th>  AIC:               </th> <td>   5370.</td>
# </tr>
# <tr>
#   <th>Df Residuals:</th>                <td>   836</td>            <th>  BIC:               </th> <td>   5389.</td>
# </tr>
# <tr>
#   <th>Df Model:</th>                    <td>     3</td>            <th>                     </th>     <td> </td>
# </tr>
# <tr>
#   <th>Covariance Type:</th>            <td>nonrobust</td>          <th>                     </th>     <td> </td>
# </tr>
# </table>
# <table class="simpletable">
# <tr>
#               <td></td>                <th>coef</th>     <th>std err</th>      <th>t</th>      <th>P>|t|</th>  <th>[0.025</th>    <th>0.975]</th>
# </tr>
# <tr>
#   <th>const</th>                    <td>   75.5983</td> <td>    1.035</td> <td>   73.044</td> <td> 0.000</td> <td>   73.567</td> <td>   77.630</td>
# </tr>
# <tr>
#   <th>init_gap</th>                 <td>    4.0316</td> <td>    0.204</td> <td>   19.806</td> <td> 0.000</td> <td>    3.632</td> <td>    4.431</td>
# </tr>
# <tr>
#   <th>cont_gap</th>                 <td>   25.0035</td> <td>    0.353</td> <td>   70.830</td> <td> 0.000</td> <td>   24.311</td> <td>   25.696</td>
# </tr>
# <tr>
#   <th>mad_temperature(degrees)</th> <td>   87.9531</td> <td>    5.959</td> <td>   14.759</td> <td> 0.000</td> <td>   76.256</td> <td>   99.650</td>
# </tr>
# </table>
# <table class="simpletable">
# <tr>
#   <th>Omnibus:</th>       <td>93.543</td> <th>  Durbin-Watson:     </th> <td>   0.454</td>
# </tr>
# <tr>
#   <th>Prob(Omnibus):</th> <td> 0.000</td> <th>  Jarque-Bera (JB):  </th> <td>  26.634</td>
# </tr>
# <tr>
#   <th>Skew:</th>          <td>-0.039</td> <th>  Prob(JB):          </th> <td>1.65e-06</td>
# </tr>
# <tr>
#   <th>Kurtosis:</th>      <td> 2.131</td> <th>  Cond. No.          </th> <td>    66.3</td>
# </tr>
# </table><br/><br/>Notes:<br/>[1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# ### Analysis segment
# <table class="simpletable">
# <caption>OLS Regression Results</caption>
# <tr>
#   <th>Dep. Variable:</th>    <td>percentage_matched_snapshots</td> <th>  R-squared:         </th> <td>   0.669</td>
# </tr>
# <tr>
#   <th>Model:</th>                         <td>OLS</td>             <th>  Adj. R-squared:    </th> <td>   0.664</td>
# </tr>
# <tr>
#   <th>Method:</th>                   <td>Least Squares</td>        <th>  F-statistic:       </th> <td>   144.0</td>
# </tr>
# <tr>
#   <th>Date:</th>                   <td>Fri, 28 Jul 2023</td>       <th>  Prob (F-statistic):</th> <td>4.42e-51</td>
# </tr>
# <tr>
#   <th>Time:</th>                       <td>21:55:36</td>           <th>  Log-Likelihood:    </th> <td> -284.36</td>
# </tr>
# <tr>
#   <th>No. Observations:</th>            <td>   218</td>            <th>  AIC:               </th> <td>   576.7</td>
# </tr>
# <tr>
#   <th>Df Residuals:</th>                <td>   214</td>            <th>  BIC:               </th> <td>   590.3</td>
# </tr>
# <tr>
#   <th>Df Model:</th>                    <td>     3</td>            <th>                     </th>     <td> </td>
# </tr>
# <tr>
#   <th>Covariance Type:</th>            <td>nonrobust</td>          <th>                     </th>     <td> </td>
# </tr>
# </table>
# <table class="simpletable">
# <tr>
#               <td></td>                <th>coef</th>     <th>std err</th>      <th>t</th>      <th>P>|t|</th>  <th>[0.025</th>    <th>0.975]</th>
# </tr>
# <tr>
#   <th>const</th>                    <td>   73.7814</td> <td>    0.310</td> <td>  238.207</td> <td> 0.000</td> <td>   73.171</td> <td>   74.392</td>
# </tr>
# <tr>
#   <th>init_gap</th>                 <td>    0.7284</td> <td>    0.072</td> <td>   10.167</td> <td> 0.000</td> <td>    0.587</td> <td>    0.870</td>
# </tr>
# <tr>
#   <th>cont_gap</th>                 <td>    2.8568</td> <td>    0.326</td> <td>    8.771</td> <td> 0.000</td> <td>    2.215</td> <td>    3.499</td>
# </tr>
# <tr>
#   <th>mad_temperature(degrees)</th> <td>   37.8445</td> <td>    1.915</td> <td>   19.759</td> <td> 0.000</td> <td>   34.069</td> <td>   41.620</td>
# </tr>
# </table>
# <table class="simpletable">
# <tr>
#   <th>Omnibus:</th>       <td>58.221</td> <th>  Durbin-Watson:     </th> <td>   1.265</td>
# </tr>
# <tr>
#   <th>Prob(Omnibus):</th> <td> 0.000</td> <th>  Jarque-Bera (JB):  </th> <td> 118.485</td>
# </tr>
# <tr>
#   <th>Skew:</th>          <td>-1.293</td> <th>  Prob(JB):          </th> <td>1.87e-26</td>
# </tr>
# <tr>
#   <th>Kurtosis:</th>      <td> 5.520</td> <th>  Cond. No.          </th> <td>    54.6</td>
# </tr>
# </table><br/><br/>Notes:<br/>[1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# # Scenario 4P exp1 ht3 hg2 4P Modelexp1 ht3 hg2 Real
# ## Affine Gap
# ### Ordered by %matched snapshots
# ### Ordered by Number of gaps
# ### Analysis all samples
# <table class="simpletable">
# <caption>OLS Regression Results</caption>
# <tr>
#   <th>Dep. Variable:</th>    <td>percentage_matched_snapshots</td> <th>  R-squared:         </th> <td>   0.962</td>
# </tr>
# <tr>
#   <th>Model:</th>                         <td>OLS</td>             <th>  Adj. R-squared:    </th> <td>   0.961</td>
# </tr>
# <tr>
#   <th>Method:</th>                   <td>Least Squares</td>        <th>  F-statistic:       </th> <td>   6985.</td>
# </tr>
# <tr>
#   <th>Date:</th>                   <td>Fri, 28 Jul 2023</td>       <th>  Prob (F-statistic):</th>  <td>  0.00</td>
# </tr>
# <tr>
#   <th>Time:</th>                       <td>21:55:41</td>           <th>  Log-Likelihood:    </th> <td> -1798.4</td>
# </tr>
# <tr>
#   <th>No. Observations:</th>            <td>   840</td>            <th>  AIC:               </th> <td>   3605.</td>
# </tr>
# <tr>
#   <th>Df Residuals:</th>                <td>   836</td>            <th>  BIC:               </th> <td>   3624.</td>
# </tr>
# <tr>
#   <th>Df Model:</th>                    <td>     3</td>            <th>                     </th>     <td> </td>
# </tr>
# <tr>
#   <th>Covariance Type:</th>            <td>nonrobust</td>          <th>                     </th>     <td> </td>
# </tr>
# </table>
# <table class="simpletable">
# <tr>
#               <td></td>                <th>coef</th>     <th>std err</th>      <th>t</th>      <th>P>|t|</th>  <th>[0.025</th>    <th>0.975]</th>
# </tr>
# <tr>
#   <th>const</th>                    <td>   67.7048</td> <td>    0.362</td> <td>  187.032</td> <td> 0.000</td> <td>   66.994</td> <td>   68.415</td>
# </tr>
# <tr>
#   <th>init_gap</th>                 <td>    3.6606</td> <td>    0.071</td> <td>   51.415</td> <td> 0.000</td> <td>    3.521</td> <td>    3.800</td>
# </tr>
# <tr>
#   <th>cont_gap</th>                 <td>   15.9856</td> <td>    0.123</td> <td>  129.468</td> <td> 0.000</td> <td>   15.743</td> <td>   16.228</td>
# </tr>
# <tr>
#   <th>mad_temperature(degrees)</th> <td>   82.0277</td> <td>    2.084</td> <td>   39.353</td> <td> 0.000</td> <td>   77.936</td> <td>   86.119</td>
# </tr>
# </table>
# <table class="simpletable">
# <tr>
#   <th>Omnibus:</th>       <td>23.679</td> <th>  Durbin-Watson:     </th> <td>   0.386</td>
# </tr>
# <tr>
#   <th>Prob(Omnibus):</th> <td> 0.000</td> <th>  Jarque-Bera (JB):  </th> <td>  12.313</td>
# </tr>
# <tr>
#   <th>Skew:</th>          <td> 0.067</td> <th>  Prob(JB):          </th> <td> 0.00212</td>
# </tr>
# <tr>
#   <th>Kurtosis:</th>      <td> 2.422</td> <th>  Cond. No.          </th> <td>    66.3</td>
# </tr>
# </table><br/><br/>Notes:<br/>[1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# ### Analysis segment
# <table class="simpletable">
# <caption>OLS Regression Results</caption>
# <tr>
#   <th>Dep. Variable:</th>    <td>percentage_matched_snapshots</td> <th>  R-squared:         </th> <td>   0.637</td>
# </tr>
# <tr>
#   <th>Model:</th>                         <td>OLS</td>             <th>  Adj. R-squared:    </th> <td>   0.610</td>
# </tr>
# <tr>
#   <th>Method:</th>                   <td>Least Squares</td>        <th>  F-statistic:       </th> <td>   23.94</td>
# </tr>
# <tr>
#   <th>Date:</th>                   <td>Fri, 28 Jul 2023</td>       <th>  Prob (F-statistic):</th> <td>4.09e-09</td>
# </tr>
# <tr>
#   <th>Time:</th>                       <td>21:55:41</td>           <th>  Log-Likelihood:    </th> <td> -49.103</td>
# </tr>
# <tr>
#   <th>No. Observations:</th>            <td>    45</td>            <th>  AIC:               </th> <td>   106.2</td>
# </tr>
# <tr>
#   <th>Df Residuals:</th>                <td>    41</td>            <th>  BIC:               </th> <td>   113.4</td>
# </tr>
# <tr>
#   <th>Df Model:</th>                    <td>     3</td>            <th>                     </th>     <td> </td>
# </tr>
# <tr>
#   <th>Covariance Type:</th>            <td>nonrobust</td>          <th>                     </th>     <td> </td>
# </tr>
# </table>
# <table class="simpletable">
# <tr>
#               <td></td>                <th>coef</th>     <th>std err</th>      <th>t</th>      <th>P>|t|</th>  <th>[0.025</th>    <th>0.975]</th>
# </tr>
# <tr>
#   <th>const</th>                    <td>   74.1753</td> <td>    0.776</td> <td>   95.646</td> <td> 0.000</td> <td>   72.609</td> <td>   75.742</td>
# </tr>
# <tr>
#   <th>init_gap</th>                 <td>    1.3515</td> <td>    0.176</td> <td>    7.682</td> <td> 0.000</td> <td>    0.996</td> <td>    1.707</td>
# </tr>
# <tr>
#   <th>cont_gap</th>                 <td>    7.9593</td> <td>    1.564</td> <td>    5.090</td> <td> 0.000</td> <td>    4.801</td> <td>   11.117</td>
# </tr>
# <tr>
#   <th>mad_temperature(degrees)</th> <td>   32.0474</td> <td>    4.939</td> <td>    6.489</td> <td> 0.000</td> <td>   22.074</td> <td>   42.021</td>
# </tr>
# </table>
# <table class="simpletable">
# <tr>
#   <th>Omnibus:</th>       <td> 1.266</td> <th>  Durbin-Watson:     </th> <td>   2.124</td>
# </tr>
# <tr>
#   <th>Prob(Omnibus):</th> <td> 0.531</td> <th>  Jarque-Bera (JB):  </th> <td>   0.821</td>
# </tr>
# <tr>
#   <th>Skew:</th>          <td>-0.330</td> <th>  Prob(JB):          </th> <td>   0.663</td>
# </tr>
# <tr>
#   <th>Kurtosis:</th>      <td> 3.050</td> <th>  Cond. No.          </th> <td>    61.5</td>
# </tr>
# </table><br/><br/>Notes:<br/>[1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# ## Simple Gap
# ### Ordered by %matched snapshots
# ### Ordered by Number of gaps
# ### Analysis all samples
# <table class="simpletable">
# <caption>OLS Regression Results</caption>
# <tr>
#   <th>Dep. Variable:</th>    <td>percentage_matched_snapshots</td> <th>  R-squared:         </th> <td>   0.962</td>
# </tr>
# <tr>
#   <th>Model:</th>                         <td>OLS</td>             <th>  Adj. R-squared:    </th> <td>   0.961</td>
# </tr>
# <tr>
#   <th>Method:</th>                   <td>Least Squares</td>        <th>  F-statistic:       </th> <td>   6985.</td>
# </tr>
# <tr>
#   <th>Date:</th>                   <td>Fri, 28 Jul 2023</td>       <th>  Prob (F-statistic):</th>  <td>  0.00</td>
# </tr>
# <tr>
#   <th>Time:</th>                       <td>21:55:44</td>           <th>  Log-Likelihood:    </th> <td> -1798.4</td>
# </tr>
# <tr>
#   <th>No. Observations:</th>            <td>   840</td>            <th>  AIC:               </th> <td>   3605.</td>
# </tr>
# <tr>
#   <th>Df Residuals:</th>                <td>   836</td>            <th>  BIC:               </th> <td>   3624.</td>
# </tr>
# <tr>
#   <th>Df Model:</th>                    <td>     3</td>            <th>                     </th>     <td> </td>
# </tr>
# <tr>
#   <th>Covariance Type:</th>            <td>nonrobust</td>          <th>                     </th>     <td> </td>
# </tr>
# </table>
# <table class="simpletable">
# <tr>
#               <td></td>                <th>coef</th>     <th>std err</th>      <th>t</th>      <th>P>|t|</th>  <th>[0.025</th>    <th>0.975]</th>
# </tr>
# <tr>
#   <th>const</th>                    <td>   67.7048</td> <td>    0.362</td> <td>  187.032</td> <td> 0.000</td> <td>   66.994</td> <td>   68.415</td>
# </tr>
# <tr>
#   <th>init_gap</th>                 <td>    3.6606</td> <td>    0.071</td> <td>   51.415</td> <td> 0.000</td> <td>    3.521</td> <td>    3.800</td>
# </tr>
# <tr>
#   <th>cont_gap</th>                 <td>   15.9856</td> <td>    0.123</td> <td>  129.468</td> <td> 0.000</td> <td>   15.743</td> <td>   16.228</td>
# </tr>
# <tr>
#   <th>mad_temperature(degrees)</th> <td>   82.0277</td> <td>    2.084</td> <td>   39.353</td> <td> 0.000</td> <td>   77.936</td> <td>   86.119</td>
# </tr>
# </table>
# <table class="simpletable">
# <tr>
#   <th>Omnibus:</th>       <td>23.679</td> <th>  Durbin-Watson:     </th> <td>   0.386</td>
# </tr>
# <tr>
#   <th>Prob(Omnibus):</th> <td> 0.000</td> <th>  Jarque-Bera (JB):  </th> <td>  12.313</td>
# </tr>
# <tr>
#   <th>Skew:</th>          <td> 0.067</td> <th>  Prob(JB):          </th> <td> 0.00212</td>
# </tr>
# <tr>
#   <th>Kurtosis:</th>      <td> 2.422</td> <th>  Cond. No.          </th> <td>    66.3</td>
# </tr>
# </table><br/><br/>Notes:<br/>[1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# ### Analysis segment
# <table class="simpletable">
# <caption>OLS Regression Results</caption>
# <tr>
#   <th>Dep. Variable:</th>    <td>percentage_matched_snapshots</td> <th>  R-squared:         </th> <td>   0.637</td>
# </tr>
# <tr>
#   <th>Model:</th>                         <td>OLS</td>             <th>  Adj. R-squared:    </th> <td>   0.610</td>
# </tr>
# <tr>
#   <th>Method:</th>                   <td>Least Squares</td>        <th>  F-statistic:       </th> <td>   23.94</td>
# </tr>
# <tr>
#   <th>Date:</th>                   <td>Fri, 28 Jul 2023</td>       <th>  Prob (F-statistic):</th> <td>4.09e-09</td>
# </tr>
# <tr>
#   <th>Time:</th>                       <td>21:55:44</td>           <th>  Log-Likelihood:    </th> <td> -49.103</td>
# </tr>
# <tr>
#   <th>No. Observations:</th>            <td>    45</td>            <th>  AIC:               </th> <td>   106.2</td>
# </tr>
# <tr>
#   <th>Df Residuals:</th>                <td>    41</td>            <th>  BIC:               </th> <td>   113.4</td>
# </tr>
# <tr>
#   <th>Df Model:</th>                    <td>     3</td>            <th>                     </th>     <td> </td>
# </tr>
# <tr>
#   <th>Covariance Type:</th>            <td>nonrobust</td>          <th>                     </th>     <td> </td>
# </tr>
# </table>
# <table class="simpletable">
# <tr>
#               <td></td>                <th>coef</th>     <th>std err</th>      <th>t</th>      <th>P>|t|</th>  <th>[0.025</th>    <th>0.975]</th>
# </tr>
# <tr>
#   <th>const</th>                    <td>   74.1753</td> <td>    0.776</td> <td>   95.646</td> <td> 0.000</td> <td>   72.609</td> <td>   75.742</td>
# </tr>
# <tr>
#   <th>init_gap</th>                 <td>    1.3515</td> <td>    0.176</td> <td>    7.682</td> <td> 0.000</td> <td>    0.996</td> <td>    1.707</td>
# </tr>
# <tr>
#   <th>cont_gap</th>                 <td>    7.9593</td> <td>    1.564</td> <td>    5.090</td> <td> 0.000</td> <td>    4.801</td> <td>   11.117</td>
# </tr>
# <tr>
#   <th>mad_temperature(degrees)</th> <td>   32.0474</td> <td>    4.939</td> <td>    6.489</td> <td> 0.000</td> <td>   22.074</td> <td>   42.021</td>
# </tr>
# </table>
# <table class="simpletable">
# <tr>
#   <th>Omnibus:</th>       <td> 1.266</td> <th>  Durbin-Watson:     </th> <td>   2.124</td>
# </tr>
# <tr>
#   <th>Prob(Omnibus):</th> <td> 0.531</td> <th>  Jarque-Bera (JB):  </th> <td>   0.821</td>
# </tr>
# <tr>
#   <th>Skew:</th>          <td>-0.330</td> <th>  Prob(JB):          </th> <td>   0.663</td>
# </tr>
# <tr>
#   <th>Kurtosis:</th>      <td> 3.050</td> <th>  Cond. No.          </th> <td>    61.5</td>
# </tr>
# </table><br/><br/>Notes:<br/>[1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
