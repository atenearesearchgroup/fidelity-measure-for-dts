# %%
import os
os.environ['NPY_ALLOW_MULTIPLE_DLLS'] = '1'

from result_analysis.statistical_graphics import generate_parallel_behavior_graphic, generate_statistical_info_stairs_variability

# %%
# FILE PATHS
current_directory = os.path.abspath(os.path.join(os.getcwd(), '../../'))
input_directory = current_directory + "/resources/input/niryo/"
output_directory = current_directory + "/resources/output/niryo/"
output_dir_var= output_directory + "/variability_eval/"

# DIGITAL TWIN
dt_path = input_directory + "digital_twin/"
dt_files = ["DT_Scenario_0", "DT_Scenario_1", "DT_Scenario_2",
           "DT_Scenario_3", "DT_Scenario_4"]

# PHYSICAL TWIN
pt_path = input_directory + "physical_twin/"
pt_files = ["PT_Scenario_0", "PT_Scenario_1", "PT_Scenario_2",
           "PT_Scenario_3", "PT_Scenario_4"]

# ANALYSIS PARAMETERS
timestamp_label = "timestamp(s)"
param_interest = "temperature(degrees)"
tolerance_label = "tolerance"

# %%
generate_parallel_behavior_graphic(timestamp_label,
                                   timestamp_label,
                                   param_interest,
                                   param_interest,
                                   pt_path+pt_files[0],
                                   dt_path+dt_file[0])
# Out:
# <div>                            <div id="51229a1d-7c0e-493a-ad22-c93db6a616fb" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("51229a1d-7c0e-493a-ad22-c93db6a616fb")) {                    Plotly.newPlot(                        "51229a1d-7c0e-493a-ad22-c93db6a616fb",                        [{"line":{"width":1},"marker":{"line":{"width":0.5},"size":3},"mode":"lines+markers","name":"PT Trajectory","x":[0.5,0.0,3.0,6.0,9.0,12.0,15.0,18.0,21.0,24.0,27.0,30.0,33.0,36.0,39.0,42.0,45.0,48.0,51.0,54.0,57.0,60.0,63.0,66.0,69.0,72.0,75.0,78.0,81.0,84.0,87.0,90.0,93.0,96.0,99.0,102.0,105.0,108.0,111.0,114.0,117.0,120.0,123.0,126.0,129.0,132.0,135.0,138.0,141.0,144.0,147.0,150.0,153.0,156.0,159.0,162.0,165.0,168.0,171.0,174.0,177.0,180.0,183.0,186.0,189.0,192.0
# ...

# %%
generate_statistical_info_stairs_variability(tolerance_label,
                                             output_dir_var,
                                             os.path.splitext(dt_file[0])[0]+os.path.splitext(pt_files[0])[0])
# Out:
# <div>                            <div id="da35748c-a3f4-4c6e-9009-bf036289e7c7" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("da35748c-a3f4-4c6e-9009-bf036289e7c7")) {                    Plotly.newPlot(                        "da35748c-a3f4-4c6e-9009-bf036289e7c7",                        [{"mode":"lines+markers","x":[0.0,0.05,0.1,0.15,0.2,0.25,0.3,0.35,0.4,0.45,0.5,0.55,0.6,0.65,0.7,0.75,0.8,0.85,0.9,0.95],"y":[0.0,73.36734693877551,75.91836734693878,78.46938775510203,80.0,81.12244897959184,81.83673469387756,82.24489795918367,82.55102040816327,83.06122448979592,83.26530612244898,83.57142857142857,83.77551020408164,84.28571428571429,84.48979591836735,84.89795918367346,85.3061224489796,85.61224489795919,85.91836734693878,86.22448979591837],"type":"s
# ...

# %%
generate_parallel_behavior_graphic(timestamp_label,
                                   timestamp_label,
                                   param_interest,
                                   param_interest,
                                   pt_path+pt_files[1],
                                   dt_path+dt_file[1])
# Out:
# <div>                            <div id="d7c09ef3-1ba8-4c35-ae46-9b3feff52019" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d7c09ef3-1ba8-4c35-ae46-9b3feff52019")) {                    Plotly.newPlot(                        "d7c09ef3-1ba8-4c35-ae46-9b3feff52019",                        [{"line":{"width":1},"marker":{"line":{"width":0.5},"size":3},"mode":"lines+markers","name":"PT Trajectory","x":[0.5,0.0,3.0,6.0,9.0,12.0,15.0,18.0,21.0,24.0,27.0,30.0,33.0,36.0,39.0,42.0,45.0,48.0,51.0,54.0,57.0,60.0,63.0,66.0,69.0,72.0,75.0,78.0,81.0,84.0,87.0,90.0,93.0,96.0,99.0,102.0,105.0,108.0,111.0,114.0,117.0,120.0,123.0,126.0,129.0,132.0,135.0,138.0,141.0,144.0,147.0,150.0,153.0,156.0,159.0,162.0,165.0,168.0,171.0,174.0,177.0,180.0,183.0,186.0,189.0,192.0
# ...

# %%
generate_statistical_info_stairs_variability(tolerance_label,
                                             output_dir_var,
                                             os.path.splitext(dt_file[1])[0]+os.path.splitext(pt_files[1])[0])
# Out:
# <div>                            <div id="8a69d8af-4b3e-4545-8bf4-5b8ecb3471fb" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8a69d8af-4b3e-4545-8bf4-5b8ecb3471fb")) {                    Plotly.newPlot(                        "8a69d8af-4b3e-4545-8bf4-5b8ecb3471fb",                        [{"mode":"lines+markers","x":[0.0,0.05,0.1,0.15,0.2,0.25,0.3,0.35,0.4,0.45,0.5,0.55,0.6,0.65,0.7,0.75,0.8,0.85,0.9,0.95],"y":[0.0,65.51020408163265,71.93877551020408,76.73469387755102,78.57142857142857,80.10204081632652,81.83673469387756,82.85714285714286,83.97959183673468,85.10204081632654,86.0204081632653,86.42857142857143,87.14285714285714,87.55102040816325,87.85714285714286,88.26530612244898,88.57142857142857,88.9795918367347,89.28571428571429,89.5918367346938
# ...

# %%
generate_parallel_behavior_graphic(timestamp_label,
                                   timestamp_label,
                                   param_interest,
                                   param_interest,
                                   pt_path+pt_files[2],
                                   dt_path+dt_file[2])
# Out:
# <div>                            <div id="ba853d0c-c115-4c1e-9c54-7381dffed9eb" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ba853d0c-c115-4c1e-9c54-7381dffed9eb")) {                    Plotly.newPlot(                        "ba853d0c-c115-4c1e-9c54-7381dffed9eb",                        [{"line":{"width":1},"marker":{"line":{"width":0.5},"size":3},"mode":"lines+markers","name":"PT Trajectory","x":[0.5,0.0,3.0,6.0,9.0,12.0,15.0,18.0,21.0,24.0,27.0,30.0,33.0,36.0,39.0,42.0,45.0,48.0,51.0,54.0,57.0,60.0,63.0,66.0,69.0,72.0,75.0,78.0,81.0,84.0,87.0,90.0,93.0,96.0,99.0,102.0,105.0,108.0,111.0,114.0,117.0,120.0,123.0,126.0,129.0,132.0,135.0,138.0,141.0,144.0,147.0,150.0,153.0,156.0,159.0,162.0,165.0,168.0,171.0,174.0,177.0,180.0,183.0,186.0,189.0,192.0
# ...

# %%
generate_statistical_info_stairs_variability(tolerance_label,
                                             output_dir_var,
                                             os.path.splitext(dt_file[2])[0]+os.path.splitext(pt_files[2])[0])
# Out:
# <div>                            <div id="d4708500-475d-4a54-9c3c-c3bd1daf67d2" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d4708500-475d-4a54-9c3c-c3bd1daf67d2")) {                    Plotly.newPlot(                        "d4708500-475d-4a54-9c3c-c3bd1daf67d2",                        [{"mode":"lines+markers","x":[0.0,0.05,0.1,0.15,0.2,0.25,0.3,0.35,0.4,0.45,0.5,0.55,0.6,0.65,0.7,0.75,0.8,0.85,0.9,0.95],"y":[0.0,49.554367201426025,51.60427807486631,53.11942959001783,54.18894830659536,54.99108734402852,55.97147950089126,56.59536541889483,57.84313725490197,60.07130124777184,60.87344028520499,62.21033868092691,63.01247771836008,64.08199643493762,64.97326203208557,66.84491978609626,67.46880570409982,69.5187165775401,70.32085561497327,71.03386809269
# ...

# %%
generate_parallel_behavior_graphic(timestamp_label,
                                   timestamp_label,
                                   param_interest,
                                   param_interest,
                                   pt_path+pt_files[3],
                                   dt_path+dt_file[3])
# Out:
# <div>                            <div id="247076c5-f29f-40b1-84ed-fb89810c719c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("247076c5-f29f-40b1-84ed-fb89810c719c")) {                    Plotly.newPlot(                        "247076c5-f29f-40b1-84ed-fb89810c719c",                        [{"line":{"width":1},"marker":{"line":{"width":0.5},"size":3},"mode":"lines+markers","name":"PT Trajectory","x":[0.5,0.0,3.0,6.0,9.0,12.0,15.0,18.0,21.0,24.0,27.0,30.0,33.0,36.0,39.0,42.0,45.0,48.0,51.0,54.0,57.0,60.0,63.0,66.0,69.0,72.0,75.0,78.0,81.0,84.0,87.0,90.0,93.0,96.0,99.0,102.0,105.0,108.0,111.0,114.0,117.0,120.0,123.0,126.0,129.0,132.0,135.0,138.0,141.0,144.0,147.0,150.0,153.0,156.0,159.0,162.0,165.0,168.0,171.0,174.0,177.0,180.0,183.0,186.0,189.0,192.0
# ...

# %%
generate_statistical_info_stairs_variability(tolerance_label,
                                             output_dir_var,
                                             os.path.splitext(dt_file[3])[0]+os.path.splitext(pt_files[3])[0])
# Out:
# <div>                            <div id="e78a9dfd-ecf6-4707-8ef4-9981fb07b0cf" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e78a9dfd-ecf6-4707-8ef4-9981fb07b0cf")) {                    Plotly.newPlot(                        "e78a9dfd-ecf6-4707-8ef4-9981fb07b0cf",                        [{"mode":"lines+markers","x":[0.0,0.05,0.1,0.15,0.2,0.25,0.3,0.35,0.4,0.45,0.5,0.55,0.6,0.65,0.7,0.75,0.8,0.85,0.9,0.95],"y":[0.0,70.85561497326202,81.81818181818183,86.72014260249554,89.66131907308377,90.9982174688057,92.42424242424242,93.31550802139036,93.85026737967914,94.11764705882352,94.6524064171123,95.36541889483064,95.72192513368984,96.2566844919786,96.4349376114082,96.524064171123,96.524064171123,96.88057040998216,96.96969696969695,97.05882352941175],"ty
# ...

# %%
generate_statistical_info_stairs_variability(tolerance_label,
                                             output_dir_var,
                                             "2P_")
# Out:
# <div>                            <div id="dcfdd02a-77aa-41a1-97dd-348e3cc0614a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("dcfdd02a-77aa-41a1-97dd-348e3cc0614a")) {                    Plotly.newPlot(                        "dcfdd02a-77aa-41a1-97dd-348e3cc0614a",                        [{"mode":"lines+markers","x":[0.0,0.05,0.1,0.15,0.2,0.25,0.3,0.35,0.4,0.45,0.5,0.55,0.6,0.65,0.7,0.75,0.8,0.85,0.9,0.95],"y":[0.0,61.46085707010077,63.76132271090255,65.79440867255994,67.09447415329768,68.05676816181018,68.90410709738441,69.42013168903925,70.19707883153262,71.56626286878388,72.06937320382698,72.89088362617774,73.39399396122086,74.18385536032596,74.73152897522647,75.87143948488486,76.38746407653971,77.56548073774965,78.11961148095602,78.62917894430
# ...

# %%
generate_statistical_info_stairs_variability(tolerance_label,
                                             output_dir_var,
                                             "4P_")
# Out:
# <div>                            <div id="74c8a867-e274-48b5-9112-9648348d1876" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("74c8a867-e274-48b5-9112-9648348d1876")) {                    Plotly.newPlot(                        "74c8a867-e274-48b5-9112-9648348d1876",                        [{"mode":"lines+markers","x":[0.0,0.05,0.1,0.15,0.2,0.25,0.3,0.35,0.4,0.45,0.5,0.55,0.6,0.65,0.7,0.75,0.8,0.85,0.9,0.95],"y":[0.0,68.18290952744734,76.87847866419295,81.72741824002328,84.11637382225618,85.5501291425661,87.13048855905998,88.0863254392666,88.9149296082069,89.60984393757502,90.3364072901888,90.89699516170103,91.43239113827349,91.90385245007093,92.14604023427553,92.39468514678599,92.54774637127579,92.93008112335843,93.12770562770562,93.32533013205281]
# ...

# %%
from result_analysis.statistical_graphics import generate_statistical_info_stairs_comparison

generate_statistical_info_stairs_comparison(tolerance_label,
                                            output_directory + os.path.splitext(dt_file[1])[0]+pt_files[1],
                                            output_directory + os.path.splitext(dt_file[0])[0]+pt_files[0])
# Out:
# <div>                            <div id="c153ea08-4b95-4c69-9ec6-09ec40de1511" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c153ea08-4b95-4c69-9ec6-09ec40de1511")) {                    Plotly.newPlot(                        "c153ea08-4b95-4c69-9ec6-09ec40de1511",                        [{"line":{"color":"#FF7F0E"},"marker":{"color":"#FF7F0E"},"mode":"lines+markers","name":"High-fidelity","x":[0.0,0.05,0.1,0.15,0.2,0.25,0.3,0.35,0.4,0.45,0.5,0.55,0.6000000000000001,0.65,0.7000000000000001,0.75,0.8,0.8500000000000001,0.9,0.95],"y":[0.0,65.51020408163265,71.93877551020408,76.73469387755102,78.57142857142857,80.10204081632652,81.83673469387756,82.85714285714286,83.97959183673468,85.10204081632654,86.0204081632653,86.42857142857143,87.14285714285714,
# ...

# %%
generate_statistical_info_stairs_comparison(tolerance_label,
                                            output_directory + os.path.splitext(dt_file[3])[0]+pt_files[3],
                                            output_directory + os.path.splitext(dt_file[2])[0]+pt_files[2])
# Out:
# <div>                            <div id="a2f817a4-6042-48d4-91aa-60ecdd3b707e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a2f817a4-6042-48d4-91aa-60ecdd3b707e")) {                    Plotly.newPlot(                        "a2f817a4-6042-48d4-91aa-60ecdd3b707e",                        [{"line":{"color":"#FF7F0E"},"marker":{"color":"#FF7F0E"},"mode":"lines+markers","name":"High-fidelity","x":[0.0,0.05,0.1,0.15,0.2,0.25,0.3,0.35,0.4,0.45,0.5,0.55,0.6000000000000001,0.65,0.7000000000000001,0.75,0.8,0.8500000000000001,0.9,0.95],"y":[0.0,70.85561497326202,81.81818181818183,86.72014260249554,89.66131907308377,90.9982174688057,92.42424242424242,93.31550802139036,93.85026737967914,94.11764705882352,94.6524064171123,95.36541889483064,95.72192513368984,9
# ...
